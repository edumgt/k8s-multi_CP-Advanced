# %% [markdown]
# # Platform Overview
#
# This notebook lives in the shared Jupyter workspace mounted into the pod.

# %%
import os

print('Python version ready for data workbench')
print('Mongo URL:', os.getenv('PLATFORM_MONGO_URL', 'mongodb://mongodb:27017/platform'))
print('Redis URL:', os.getenv('PLATFORM_REDIS_URL', 'redis://redis:6379/0'))
